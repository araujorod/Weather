# %%
path = '../data/weather_data.json'

import pandas as pd

import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)

df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id      name  cod  coord.lon  coord.lat  ...  \
# 0  1780879935    -10800  3469968  Blumenau  200   -49.0661   -26.9194  ...
#
#    main.grnd_level  wind.speed  wind.deg  wind.gust  clouds.all  sys.type  \
# 0              995        0.47        84       0.31          37         2
#
#     sys.id  sys.country  sys.sunrise  sys.sunset
# 0  2109788           BR   1780826420  1780864212
#
# [1 rows x 27 columns]
